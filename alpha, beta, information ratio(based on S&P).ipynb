# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web   
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import norm
import datetime
import cufflinks as cf
import plotly.offline as plyo
import plotly as ply
import plotly.graph_objs as go
import yfinance as yf

plyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Daily_return = pd.read_excel('/Users/andy/Desktop/PM/Daily_return.xlsx')
Daily_return = Daily_return.set_index('Date')
Daily_return.head()
# Out:
#                GOOGL       JPM      MSFT      AAPL        VZ      AMZN  \
# Date
# 2015-01-02 -0.002092  0.004985  0.006674 -0.009513  0.003848 -0.005897
# 2015-01-05 -0.019054 -0.031045 -0.009196 -0.028172 -0.008305 -0.020517
# 2015-01-06 -0.024679 -0.025929 -0.014677  0.000094  0.010092 -0.022833
# 2015-01-07 -0.002941  0.001526  0.012705  0.014022 -0.006453  0.010600
# 2015-01-08  0.003484  0.022347  0.029418  0.038422  0.021433  0.006836
#
#                  JNJ       MMM     BRK-B       BMY      Fund  \
# Date
# 2015-01-02 -0.000478 -0.001582 -0.006527  0.008131  0.000000
# 2015-01-05 -0.006984 -0.022553 -0.014547 -0.015627 -0.016116
# 2015-01-06 -0.004914 -0.010663 -0.001088 -0.001707 -0.008056
# 2015-01-07  0.022076  0.007249  0.013893  0.012996  0.012182
# 2015-01-08  0.007863  0.023967  0.016725  0.024983  0.016582
#
#             Optimal Risky Portfolio  Minimum Variance Portfolio  \
# Date
# 2015-01-02                -0.000308                   -0.001583
# 2015-01-05                -0.017939                   -0.012707
# 2015-01-06                -0.012980                   -0.003131
# 2015-01-07                 0.006513                    0.008796
# 2015-01-08                 0.018920                    0.014897
#
#             Equally Weight Portfolio      MSCI   S&P 500
# Date
# 2015-01-02                 -0.000245 -0.002907 -0.000340
# 2015-01-05                 -0.017600 -0.019628 -0.018278
# 2015-01-06                 -0.009631 -0.010094 -0.008894
# 2015-01-07                  0.008567  0.004739  0.011630
# 2015-01-08                  0.019548  0.019221  0.017888

# %%
from scipy import stats
import statsmodels.api as sm

Cols = Daily_return.columns[0:14]
Cols
# Out:
# Index(['GOOGL', 'JPM', 'MSFT', 'AAPL', 'VZ', 'AMZN', 'JNJ', 'MMM', 'BRK-B',
#        'BMY', 'Fund', 'Optimal Risky Portfolio', 'Minimum Variance Portfolio',
#        'Equally Weight Portfolio'],
#       dtype='object')

# %%
x = Daily_return.loc[:, 'S&P 500'].values
y = Daily_return.iloc[:, 0:14].values

AB_5y = pd.DataFrame()
alpha_5y = []
beta_5y = []

for i in range(14):
    b, a, r_value, p_value, std_err = stats.linregress(x, y[:, i])
    # annualize alpha
    alpha_5y.append(round(a * 250, 4))
    beta_5y.append(round(b, 4))
    
AB_5y['alpha_5y'] = alpha_5y
AB_5y['beta_5y'] = beta_5y
AB_5y.index = Cols

AB_5y
# Out:
#                             alpha_5y  beta_5y
# GOOGL                         0.0951   1.1851
# JPM                           0.0926   1.1750
# MSFT                          0.1615   1.3180
# AAPL                          0.1198   1.2399
# VZ                            0.0597   0.5473
# AMZN                          0.2666   1.3201
# JNJ                           0.0388   0.6896
# MMM                          -0.0368   0.9843
# BRK-B                        -0.0018   0.9863
# BMY                          -0.0068   0.8345
# Fund                         -0.0798   0.9710
# Optimal Risky Portfolio       0.1676   1.1332
# Minimum Variance Portfolio    0.0388   0.8562
# Equally Weight Portfolio      0.0789   1.0280

# %%
ret_2017_2019 = Daily_return[(Daily_return.index >= pd.to_datetime('20170101')) & (Daily_return.index <= pd.to_datetime('20191231'))]
ret_2017_2019.head()
# Out:
#                GOOGL       JPM      MSFT      AAPL        VZ      AMZN  \
# Date
# 2017-01-03  0.019635  0.010894  0.007081  0.002849  0.022480  0.005068
# 2017-01-04 -0.000297  0.001844 -0.004474 -0.001119 -0.001099  0.004657
# 2017-01-05  0.006499 -0.009205  0.000000  0.005085  0.002201  0.030732
# 2017-01-06  0.014993  0.000116  0.008668  0.011148 -0.014835  0.019912
# 2017-01-09  0.002387  0.000697 -0.003183  0.009159 -0.010890  0.001168
#
#                  JNJ       MMM     BRK-B       BMY      Fund  \
# Date
# 2017-01-03  0.005468 -0.002912  0.005215  0.017283  0.008966
# 2017-01-04 -0.001640  0.001516  0.001526  0.001355  0.006109
# 2017-01-05  0.010463 -0.003421 -0.004754  0.016740 -0.003312
# 2017-01-06 -0.004792  0.002926  0.000674 -0.002993  0.002215
# 2017-01-09 -0.000172 -0.005386 -0.008506 -0.003670 -0.003592
#
#             Optimal Risky Portfolio  Minimum Variance Portfolio  \
# Date
# 2017-01-03                 0.009664                    0.011719
# 2017-01-04                 0.000865                   -0.000117
# 2017-01-05                 0.011364                    0.003345
# 2017-01-06                 0.007139                   -0.001548
# 2017-01-09                -0.001542                   -0.004650
#
#             Equally Weight Portfolio      MSCI   S&P 500
# Date
# 2017-01-03                  0.009306  0.002795  0.008487
# 2017-01-04                  0.000227  0.009084  0.005722
# 2017-01-05                  0.005434  0.004792 -0.000771
# 2017-01-06                  0.003582  0.000359  0.003517
# 2017-01-09                 -0.001840 -0.003455 -0.003549

# %%
x = ret_2017_2019.loc[:, 'S&P 500'].values
y = ret_2017_2019.iloc[:, 0:14].values

AB_3y = pd.DataFrame()
alpha_3y = []
beta_3y = []

for i in range(14):
    b, a, r_value, p_value, std_err = stats.linregress(x, y[:, i])
    # annualize alpha
    alpha_3y.append(round(a * 250, 4))
    beta_3y.append(round(b, 4))
    
AB_3y['alpha_3y'] = alpha_3y
AB_3y['beta_3y'] = beta_3y
AB_3y.index = Cols

AB_3y
# Out:
#                             alpha_3y  beta_3y
# GOOGL                         0.0287   1.3227
# JPM                           0.0667   1.0613
# MSFT                          0.1707   1.3822
# AAPL                          0.1769   1.3650
# VZ                            0.0493   0.4451
# AMZN                          0.1425   1.4942
# JNJ                           0.0328   0.6687
# MMM                          -0.0961   1.0960
# BRK-B                        -0.0094   1.0221
# BMY                          -0.0122   0.7964
# Fund                         -0.0896   0.9893
# Optimal Risky Portfolio       0.1210   1.1857
# Minimum Variance Portfolio    0.0243   0.8642
# Equally Weight Portfolio      0.0550   1.0654

# %%
# Tracking return
TR = []

for asset in Cols:
    tr = Daily_return.loc[:, asset] - Daily_return.iloc[:, -1]
    TR.append(tr)

TR_T = pd.DataFrame(TR)
TR = TR_T.T
TR.columns = Cols
TR.head()
# Out:
#                GOOGL       JPM      MSFT      AAPL        VZ      AMZN  \
# Date
# 2015-01-02 -0.001752  0.005325  0.007014 -0.009173  0.004188 -0.005557
# 2015-01-05 -0.000776 -0.012767  0.009083 -0.009894  0.009973 -0.002239
# 2015-01-06 -0.015786 -0.017036 -0.005784  0.008988  0.018986 -0.013940
# 2015-01-07 -0.014571 -0.010104  0.001075  0.002392 -0.018083 -0.001030
# 2015-01-08 -0.014404  0.004458  0.011530  0.020534  0.003545 -0.011052
#
#                  JNJ       MMM     BRK-B       BMY      Fund  \
# Date
# 2015-01-02 -0.000138 -0.001242 -0.006187  0.008471  0.000340
# 2015-01-05  0.011294 -0.004275  0.003731  0.002651  0.002162
# 2015-01-06  0.003979 -0.001770  0.007805  0.007186  0.000838
# 2015-01-07  0.010447 -0.004381  0.002263  0.001366  0.000552
# 2015-01-08 -0.010026  0.006079 -0.001163  0.007095 -0.001306
#
#             Optimal Risky Portfolio  Minimum Variance Portfolio  \
# Date
# 2015-01-02                 0.000032                   -0.001243
# 2015-01-05                 0.000340                    0.005571
# 2015-01-06                -0.004086                    0.005763
# 2015-01-07                -0.005117                   -0.002834
# 2015-01-08                 0.001031                   -0.002992
#
#             Equally Weight Portfolio
# Date
# 2015-01-02                  0.000095
# 2015-01-05                  0.000678
# 2015-01-06                 -0.000737
# 2015-01-07                 -0.003063
# 2015-01-08                  0.001660

# %%
information_ratio = np.sqrt(len(TR)) * TR.mean() / TR.std()

INR = pd.DataFrame(information_ratio, columns=['Information ratio'])
INR
# Out:
#                             Information ratio
# GOOGL                                1.431793
# JPM                                  1.762907
# MSFT                                 2.757907
# AAPL                                 1.728264
# VZ                                   0.205145
# AMZN                                 2.839935
# JNJ                                  0.131561
# MMM                                 -0.598411
# BRK-B                               -0.071350
# BMY                                 -0.225291
# Fund                                -2.916395
# Optimal Risky Portfolio              3.980755
# Minimum Variance Portfolio           0.845810
# Equally Weight Portfolio             3.548139

# %%
indicators = pd.concat([AB_3y, AB_5y, INR], axis=1, sort=False)

indicators
# Out:
#                             alpha_3y  beta_3y  alpha_5y  beta_5y  \
# GOOGL                         0.0287   1.3227    0.0951   1.1851
# JPM                           0.0667   1.0613    0.0926   1.1750
# MSFT                          0.1707   1.3822    0.1615   1.3180
# AAPL                          0.1769   1.3650    0.1198   1.2399
# VZ                            0.0493   0.4451    0.0597   0.5473
# AMZN                          0.1425   1.4942    0.2666   1.3201
# JNJ                           0.0328   0.6687    0.0388   0.6896
# MMM                          -0.0961   1.0960   -0.0368   0.9843
# BRK-B                        -0.0094   1.0221   -0.0018   0.9863
# BMY                          -0.0122   0.7964   -0.0068   0.8345
# Fund                         -0.0896   0.9893   -0.0798   0.9710
# Optimal Risky Portfolio       0.1210   1.1857    0.1676   1.1332
# Minimum Variance Portfolio    0.0243   0.8642    0.0388   0.8562
# Equally Weight Portfolio      0.0550   1.0654    0.0789   1.0280
#
#                             Information ratio
# GOOGL                                1.431793
# JPM                                  1.762907
# MSFT                                 2.757907
# AAPL                                 1.728264
# VZ                                   0.205145
# AMZN                                 2.839935
# JNJ                                  0.131561
# MMM                                 -0.598411
# BRK-B                               -0.071350
# BMY                                 -0.225291
# Fund                                -2.916395
# Optimal Risky Portfolio              3.980755
# Minimum Variance Portfolio           0.845810
# Equally Weight Portfolio             3.548139
